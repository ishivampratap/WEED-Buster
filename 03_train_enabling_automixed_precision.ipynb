# %% [markdown]
# # Enable Auto-Mixed Precision for Transfer Learning with TensorFlow
#
# This notebook performs the following steps:
#
# - Enable auto-mixed precision with a single-line change.
# - Transfer-Learning for Image Classification using [TensorFlow Hub's](https://www.tensorflow.org/hub) ResNet50v1.5 pretrained model.
# - Export the fine-tuned model in the [SavedModel](https://www.tensorflow.org/guide/saved_model) format.
# - Optimize the SavedModel for faster inference.
# - Serve the SavedModel using [TensorFlow Serving](https://www.tensorflow.org/tfx/guide/serving).

# %%
import config_setup

arch = config_setup.arch_checker().arch
print("Arch: ", arch)
# Out:
# TensorTlow version:  2.9.1
# MKL enabled : True
# scikit learn Version:  1.1.1
# neural_compressor version 1.13
# Arch:  BDW|CORE|ATOM

# %%
# Importing libraries
import os
import numpy as np
import time
import PIL.Image as Image
import tensorflow as tf
import tensorflow_hub as hub
from datetime import datetime
import requests
from copy import deepcopy
import wandb
from wandb.keras import WandbMetricsLogger
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, roc_curve, auc
import matplotlib.pyplot as plt
import itertools
print("We are using Tensorflow version: ", tf.__version__)
# Out:
# We are using Tensorflow version:  2.9.1

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %% [markdown]
# ### Identifying supported ISA
#
# We identify the underlying supported ISA to determine whether to enable auto-mixed precision to leverage higher performance benefits for training and inference as accelerated by the 4th Gen Intel® Xeon® scalable processor (codenamed Sapphire Rapids).

# %% [markdown]
# ### Transfer Learning for Image Classification with TensorFlow

# %% [markdown]
# In this section, we use [TensorFlow Hub's](https://www.tensorflow.org/hub) pretrained [ResNet50v1.5 pretrained model](https://tfhub.dev/google/imagenet/resnet_v1_50/feature_vector/5) originally trained on the ImageNet dataset and perform transfer learning to fine-tune the model for your own image classes.
#
# Source: https://www.tensorflow.org/tutorials/images/transfer_learning_with_hub

# %% [markdown]
# In this example, we use the **TensorFlow Flower dataset**
#
# Loading the data in a *tf.data.Dataset* format.<br />
# We use a Batch Size of 512 images each of shape 224 x 224 x 3.

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
data_root = ('./dataset/datafile/')

batch_size = 64
img_height = 224
img_width = 224

train_ds = tf.keras.utils.image_dataset_from_directory(
  str(data_root),
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
  str(data_root),
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size
)

class_names = np.array(train_ds.class_names)
print("The crop weed dataset has " + str(len(class_names)) + " classes: ", class_names)
# Out:
# Found 1302 files belonging to 2 classes.
# Using 1042 files for training.
# Found 1302 files belonging to 2 classes.
# Using 260 files for validation.
# The crop weed dataset has 2 classes:  ['crop' 'weed']
# 2023-03-27 20:18:27.477750: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 20:18:27.478955: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting:

# %% [markdown]
# Image Pre-processing (Normalization between 0 and 1) and using buffered prefetching to avoid I/O blocking issues.
#
# Reference: https://www.tensorflow.org/guide/data_performance#prefetching

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y)) # Where x—images, y—labels.
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y)) # Where x—images, y—labels.

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)
# 2023-03-27 20:18:32.061348: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# **Simple Transfer Learning:**<br />
#     1. *Select a pre-trained model from TensorFlow Hub*.<br />
#     2. *Retrain the top (last) layer to recognize the classes from your custom dataset*.<br /><br />
#
# We use a **headless ResNet50v1.5 pretrained model** (without the classification layer). Any compatible image feature vector model from TF-Hub (https://tfhub.dev/s?module-type=image-feature-vector&q=tf2) can be used here.

# %%
resnet_feature_vector = "https://tfhub.dev/google/imagenet/resnet_v1_101/feature_vector/5"

feature_extractor_model = resnet_feature_vector

# %% [markdown]
# Create the feature extractor by wrapping the pre-trained model as a Keras layer with **hub.KerasLayer**. Use the ***trainable=False*** argument to freeze the variables, so that the training only modifies the new classifier layer:

# %%
feature_extractor_layer = hub.KerasLayer(
    feature_extractor_model,
    input_shape=(224, 224, 3),
    trainable=False)

feature_batch = feature_extractor_layer(image_batch)
# Out:
# 2023-03-27 20:18:36 [INFO] Using /tmp/tfhub_modules to cache modules.

# %% [markdown]
# Attach the last fully connected classification layer in a **tf.keras.Sequential** model.

# %%
num_classes = len(class_names)

fp32_model = tf.keras.Sequential([
  feature_extractor_layer,
  tf.keras.layers.Dense(1024, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])

bf16_model = deepcopy(fp32_model)
# if arch == 'BDW|CORE|ATOM':
#     # Create a deep copy of the model to train the bf16 model separately to compare accuracy
#     bf16_model = deepcopy(fp32_model)

fp32_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 2048)              42605504
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 45,403,106
# Trainable params: 2,797,602
# Non-trainable params: 42,605,504
# _________________________________________________________________

# %% [markdown]
# In order to measure the training throughput, we define the following custom callback. For more information on callbacks, refer to https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback.

# %%
class TimeHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []
        self.throughput = []

    def on_batch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_batch_end(self, batch, logs={}):
        total_time = time.time() - self.epoch_time_start
        self.times.append(total_time)
        self.throughput.append(batch_size/total_time)

# %% [markdown]
# #### Compile and train the model

# %%
fp32_model.compile(
  optimizer=tf.keras.optimizers.SGD(),
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

# %%
train_throughput_list = []

# %% [markdown]
# #### Train without auto-mixed precision (float32)

# %%
NUM_EPOCHS = 50

# %%
configs = dict(
    num_classes = num_classes,
    shuffle_buffer = 42,
    batch_size = batch_size,
    image_size = 224,
    image_channels = 3,
    earlystopping_patience = 3,
    learning_rate = 1e-3,
    epochs = NUM_EPOCHS
)

# %%
# Initialize a W&B run
run = wandb.init(
    project = "Automated-Weed-Detection-AMP",
    config = configs
)

time_callback = TimeHistory()
history = fp32_model.fit(train_ds, validation_data=val_ds, epochs=NUM_EPOCHS, callbacks=[time_callback, WandbMetricsLogger(log_freq=10)])
avg_throughput = sum(time_callback.throughput)/len(time_callback.throughput)
print("Avg Throughput: " + str(avg_throughput) + " imgs/sec")
train_throughput_list.append(avg_throughput)
# Out:
# Finishing last run (ID:s8xm56va) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/acc</td><td>▁</td></tr><tr><td>batch/batch_step</td><td>▁</td></tr><tr><td>batch/learning_rate</td><td>▁</td></tr><tr><td>batch/loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/acc</td><td>0.5</td></tr><tr><td>batch/batch_step</td><td>0</td></tr><tr><td>batch/learning_rate</td><td>0.01</td></tr><tr><td>batch/loss</td><td>1.87926</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br/><code>wandb sync /home/mnitin59/Downloads/Automated-Weed-Detection/wandb/offline-run-20230327_201902-s8xm56va<code>
# Find logs at: <code>./wandb/offline-run-20230327_201902-s8xm56va/logs</code>
# Successfully finished last run (ID:s8xm56va). Initializing new run:<br/>
# Tracking run with wandb version 0.14.0
# W&B syncing is set to <code>`offline`<code> in this directory.  <br/>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# Epoch 1/50
# 17/17 [==============================] - ETA: 0s - loss: 0.8942 - acc: 0.5048
# /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 17/17 [==============================] - 67s 4s/step - loss: 0.8942 - acc: 0.5048 - val_loss: 0.6817 - val_acc: 0.5923
# Epoch 2/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.7983 - acc: 0.5221 - val_loss: 0.6750 - val_acc: 0.5462
# Epoch 3/50
# 17/17 [==============================] - 74s 4s/step - loss: 0.7444 - acc: 0.5441 - val_loss: 0.6754 - val_acc: 0.5692
# Epoch 4/50
# 17/17 [==============================] - 71s 4s/step - loss: 0.7490 - acc: 0.5125 - val_loss: 0.6661 - val_acc: 0.6846
# Epoch 5/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.7121 - acc: 0.5441 - val_loss: 0.6726 - val_acc: 0.6000
# Epoch 6/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.7040 - acc: 0.5614 - val_loss: 0.6675 - val_acc: 0.6577
# Epoch 7/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.6988 - acc: 0.5384 - val_loss: 0.6562 - val_acc: 0.7308
# Epoch 8/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.7088 - acc: 0.5557 - val_loss: 0.6514 - val_acc: 0.8000
# Epoch 9/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.6787 - acc: 0.5729 - val_loss: 0.6377 - val_acc: 0.8423
# Epoch 10/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.6649 - acc: 0.5883 - val_loss: 0.6215 - val_acc: 0.8846
# Epoch 11/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.6423 - acc: 0.6430 - val_loss: 0.5975 - val_acc: 0.9269
# Epoch 12/50
# 17/17 [==============================] - 79s 5s/step - loss: 0.6374 - acc: 0.6430 - val_loss: 0.5707 - val_acc: 0.9385
# Epoch 13/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.6131 - acc: 0.6449 - val_loss: 0.5386 - val_acc: 0.9462
# Epoch 14/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.5798 - acc: 0.6900 - val_loss: 0.4960 - val_acc: 0.9500
# Epoch 15/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.5583 - acc: 0.7111 - val_loss: 0.4384 - val_acc: 0.9346
# Epoch 16/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.5110 - acc: 0.7572 - val_loss: 0.3820 - val_acc: 0.9385
# Epoch 17/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.5011 - acc: 0.7639 - val_loss: 0.3445 - val_acc: 0.9385
# Epoch 18/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.4660 - acc: 0.7687 - val_loss: 0.3041 - val_acc: 0.9500
# Epoch 19/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.4222 - acc: 0.8052 - val_loss: 0.2790 - val_acc: 0.9462
# Epoch 20/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.4322 - acc: 0.8071 - val_loss: 0.2560 - val_acc: 0.9500
# Epoch 21/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.3874 - acc: 0.8330 - val_loss: 0.2370 - val_acc: 0.9500
# Epoch 22/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.3775 - acc: 0.8301 - val_loss: 0.2250 - val_acc: 0.9538
# Epoch 23/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.3557 - acc: 0.8474 - val_loss: 0.2152 - val_acc: 0.9538
# Epoch 24/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.3406 - acc: 0.8820 - val_loss: 0.2061 - val_acc: 0.9538
# Epoch 25/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.3291 - acc: 0.8954 - val_loss: 0.1962 - val_acc: 0.9538
# Epoch 26/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.3179 - acc: 0.8676 - val_loss: 0.1894 - val_acc: 0.9538
# Epoch 27/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2878 - acc: 0.8916 - val_loss: 0.1850 - val_acc: 0.9615
# Epoch 28/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2993 - acc: 0.8935 - val_loss: 0.1847 - val_acc: 0.9615
# Epoch 29/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2908 - acc: 0.9079 - val_loss: 0.1839 - val_acc: 0.9615
# Epoch 30/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2988 - acc: 0.9098 - val_loss: 0.1844 - val_acc: 0.9615
# Epoch 31/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.3129 - acc: 0.9021 - val_loss: 0.1820 - val_acc: 0.9615
# Epoch 32/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2852 - acc: 0.9146 - val_loss: 0.1813 - val_acc: 0.9615
# Epoch 33/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2690 - acc: 0.9098 - val_loss: 0.1812 - val_acc: 0.9615
# Epoch 34/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.3002 - acc: 0.9203 - val_loss: 0.1801 - val_acc: 0.9654
# Epoch 35/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2964 - acc: 0.9232 - val_loss: 0.1803 - val_acc: 0.9615
# Epoch 36/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2578 - acc: 0.9232 - val_loss: 0.1776 - val_acc: 0.9615
# Epoch 37/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2710 - acc: 0.9213 - val_loss: 0.1740 - val_acc: 0.9615
# Epoch 38/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2514 - acc: 0.9203 - val_loss: 0.1751 - val_acc: 0.9615
# Epoch 39/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2850 - acc: 0.9223 - val_loss: 0.1738 - val_acc: 0.9615
# Epoch 40/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2654 - acc: 0.9319 - val_loss: 0.1746 - val_acc: 0.9615
# Epoch 41/50
# 17/17 [==============================] - 65s 4s/step - loss: 0.2503 - acc: 0.9290 - val_loss: 0.1727 - val_acc: 0.9615
# Epoch 42/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2434 - acc: 0.9338 - val_loss: 0.1727 - val_acc: 0.9577
# Epoch 43/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2177 - acc: 0.9367 - val_loss: 0.1729 - val_acc: 0.9615
# Epoch 44/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2377 - acc: 0.9395 - val_loss: 0.1724 - val_acc: 0.9577
# Epoch 45/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2229 - acc: 0.9376 - val_loss: 0.1737 - val_acc: 0.9577
# Epoch 46/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2421 - acc: 0.9405 - val_loss: 0.1704 - val_acc: 0.9577
# Epoch 47/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2768 - acc: 0.9367 - val_loss: 0.1711 - val_acc: 0.9615
# Epoch 48/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2320 - acc: 0.9376 - val_loss: 0.1700 - val_acc: 0.9615
# Epoch 49/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2163 - acc: 0.9463 - val_loss: 0.1707 - val_acc: 0.9615
# Epoch 50/50
# 17/17 [==============================] - 80s 5s/step - loss: 0.2253 - acc: 0.9463 - val_loss: 0.1722 - val_acc: 0.9615
# Avg Throughput: 21.73333016090273 imgs/sec

# %% [markdown]
# ### Enabling auto-mixed precision with `tf.config` API
#
# In this section, we show how to enable the auto-mixed precision using the `tf.config` API. Enabling this API will automatically convert the pre-trained model to use the bfloat16 datatype for computation resulting in an increased training throughput on the latest Intel® Xeon® scalable processor.
#
# You can also print the following to see whether the auto-mixed precision has been enabled.
#
# _Note: We only enable the auto-mixed precision if the underlying system is the 4th Gen Intel® Xeon® scalable processor (codenamed Sapphire Rapids)_

# %%
if arch == 'BDW|CORE|ATOM':
    tf.config.optimizer.set_experimental_options({'auto_mixed_precision_onednn_bfloat16':True})
    print(tf.config.optimizer.get_experimental_options())
# Out:
# {'disable_model_pruning': False, 'disable_meta_optimizer': False}

# %% [markdown]
# #### Compile and train the model with auto-mixed precision (bfloat16)

# %%
if arch == 'BDW|CORE|ATOM':
    # Initialize a W&B run
    run = wandb.init(
        project = "Automated-Weed-Detection-AMP",
        config = configs
    )
    # Compile
    bf16_model.compile(
      optimizer=tf.keras.optimizers.SGD(),
      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
      metrics=['acc'])
    
    # Train
    NUM_EPOCHS = 50
    time_callback = TimeHistory()
    history = bf16_model.fit(train_ds, validation_data=val_ds, epochs=NUM_EPOCHS, callbacks=[time_callback, WandbMetricsLogger(log_freq=10)])
    avg_throughput = sum(time_callback.throughput)/len(time_callback.throughput)
    print("Avg Throughput: " + str(avg_throughput) + " imgs/sec")
    train_throughput_list.append(avg_throughput)
    
    model = bf16_model
else:
    model = fp32_model
# Out:
# Finishing last run (ID:px0ktzot) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/acc</td><td>▃▂▂▂▁▄▂▂▂▅▃▄▆▅▅▆▆▆▆▇▇▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>batch/batch_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>batch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>██▇▇█▆▇▇▆▆▆▅▄▅▄▃▃▄▃▂▃▃▃▁▂▃▁▁▂▂▁▁▂▂▁▁▂▃▁▂</td></tr><tr><td>epoch/acc</td><td>▁▁▂▁▂▂▂▂▃▃▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▇▆▆▆▆▆▆▅▅▅▅▄▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▂▁▁▁▁▁▂▁▁</td></tr><tr><td>epoch/val_acc</td><td>▂▁▁▃▃▄▅▆▇███████████████████████████████</td></tr><tr><td>epoch/val_loss</td><td>███████▇▇▆▆▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/acc</td><td>0.94602</td></tr><tr><td>batch/batch_step</td><td>990</td></tr><tr><td>batch/learning_rate</td><td>0.01</td></tr><tr><td>batch/loss</td><td>0.22061</td></tr><tr><td>epoch/acc</td><td>0.94626</td></tr><tr><td>epoch/epoch</td><td>49</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>0.22533</td></tr><tr><td>epoch/val_acc</td><td>0.96154</td></tr><tr><td>epoch/val_loss</td><td>0.17223</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br/><code>wandb sync /home/mnitin59/Downloads/Automated-Weed-Detection/wandb/offline-run-20230327_201951-px0ktzot<code>
# Find logs at: <code>./wandb/offline-run-20230327_201951-px0ktzot/logs</code>
# Successfully finished last run (ID:px0ktzot). Initializing new run:<br/>
# Tracking run with wandb version 0.14.0
# W&B syncing is set to <code>`offline`<code> in this directory.  <br/>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# Epoch 1/50
# /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 17/17 [==============================] - 72s 4s/step - loss: 1.1789 - acc: 0.4818 - val_loss: 0.6877 - val_acc: 0.5731
# Epoch 2/50
# 17/17 [==============================] - 65s 4s/step - loss: 0.8499 - acc: 0.5163 - val_loss: 0.6670 - val_acc: 0.6154
# Epoch 3/50
# 17/17 [==============================] - 74s 4s/step - loss: 0.8209 - acc: 0.4990 - val_loss: 0.6848 - val_acc: 0.5615
# Epoch 4/50
# 17/17 [==============================] - 69s 4s/step - loss: 0.7542 - acc: 0.5365 - val_loss: 0.6808 - val_acc: 0.5577
# Epoch 5/50
# 17/17 [==============================] - 69s 4s/step - loss: 0.7360 - acc: 0.5413 - val_loss: 0.6775 - val_acc: 0.6115
# Epoch 6/50
# 17/17 [==============================] - 73s 4s/step - loss: 0.7264 - acc: 0.5470 - val_loss: 0.6684 - val_acc: 0.6615
# Epoch 7/50
# 17/17 [==============================] - 74s 4s/step - loss: 0.7094 - acc: 0.5461 - val_loss: 0.6583 - val_acc: 0.7962
# Epoch 8/50
# 17/17 [==============================] - 75s 4s/step - loss: 0.7182 - acc: 0.5432 - val_loss: 0.6544 - val_acc: 0.8269
# Epoch 9/50
# 17/17 [==============================] - 74s 4s/step - loss: 0.6956 - acc: 0.5835 - val_loss: 0.6499 - val_acc: 0.9154
# Epoch 10/50
# 17/17 [==============================] - 73s 4s/step - loss: 0.6785 - acc: 0.5940 - val_loss: 0.6416 - val_acc: 0.8731
# Epoch 11/50
# 17/17 [==============================] - 74s 4s/step - loss: 0.6495 - acc: 0.6046 - val_loss: 0.6162 - val_acc: 0.9154
# Epoch 12/50
# 17/17 [==============================] - 76s 5s/step - loss: 0.6455 - acc: 0.6267 - val_loss: 0.5884 - val_acc: 0.9462
# Epoch 13/50
# 17/17 [==============================] - 118s 7s/step - loss: 0.6252 - acc: 0.6401 - val_loss: 0.5539 - val_acc: 0.9500
# Epoch 14/50
# 17/17 [==============================] - 99s 6s/step - loss: 0.6018 - acc: 0.6679 - val_loss: 0.5114 - val_acc: 0.9500
# Epoch 15/50
# 17/17 [==============================] - 85s 5s/step - loss: 0.5631 - acc: 0.7169 - val_loss: 0.4570 - val_acc: 0.9423
# Epoch 16/50
# 17/17 [==============================] - 77s 5s/step - loss: 0.5573 - acc: 0.7092 - val_loss: 0.4157 - val_acc: 0.9500
# Epoch 17/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.5218 - acc: 0.7409 - val_loss: 0.3841 - val_acc: 0.9462
# Epoch 18/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.5001 - acc: 0.7620 - val_loss: 0.3584 - val_acc: 0.9385
# Epoch 19/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.4561 - acc: 0.8033 - val_loss: 0.3255 - val_acc: 0.9500
# Epoch 20/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.4303 - acc: 0.7917 - val_loss: 0.2913 - val_acc: 0.9462
# Epoch 21/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.4179 - acc: 0.8301 - val_loss: 0.2639 - val_acc: 0.9500
# Epoch 22/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.3677 - acc: 0.8426 - val_loss: 0.2427 - val_acc: 0.9423
# Epoch 23/50
# 17/17 [==============================] - 65s 4s/step - loss: 0.3715 - acc: 0.8637 - val_loss: 0.2284 - val_acc: 0.9538
# Epoch 24/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.3156 - acc: 0.8839 - val_loss: 0.2167 - val_acc: 0.9615
# Epoch 25/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.3645 - acc: 0.8704 - val_loss: 0.2110 - val_acc: 0.9577
# Epoch 26/50
# 17/17 [==============================] - 72s 4s/step - loss: 0.3456 - acc: 0.8656 - val_loss: 0.2013 - val_acc: 0.9577
# Epoch 27/50
# 17/17 [==============================] - 73s 4s/step - loss: 0.2930 - acc: 0.8896 - val_loss: 0.1991 - val_acc: 0.9615
# Epoch 28/50
# 17/17 [==============================] - 75s 4s/step - loss: 0.3655 - acc: 0.8906 - val_loss: 0.1938 - val_acc: 0.9615
# Epoch 29/50
# 17/17 [==============================] - 81s 5s/step - loss: 0.3039 - acc: 0.9012 - val_loss: 0.1921 - val_acc: 0.9615
# Epoch 30/50
# 17/17 [==============================] - 75s 4s/step - loss: 0.3590 - acc: 0.8944 - val_loss: 0.1858 - val_acc: 0.9615
# Epoch 31/50
# 17/17 [==============================] - 77s 5s/step - loss: 0.2914 - acc: 0.8973 - val_loss: 0.1844 - val_acc: 0.9654
# Epoch 32/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2743 - acc: 0.9079 - val_loss: 0.1798 - val_acc: 0.9615
# Epoch 33/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.3039 - acc: 0.8944 - val_loss: 0.1795 - val_acc: 0.9615
# Epoch 34/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2646 - acc: 0.9088 - val_loss: 0.1772 - val_acc: 0.9654
# Epoch 35/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2852 - acc: 0.9146 - val_loss: 0.1775 - val_acc: 0.9615
# Epoch 36/50
# 17/17 [==============================] - 70s 4s/step - loss: 0.2752 - acc: 0.9203 - val_loss: 0.1766 - val_acc: 0.9615
# Epoch 37/50
# 17/17 [==============================] - 75s 4s/step - loss: 0.2505 - acc: 0.9290 - val_loss: 0.1767 - val_acc: 0.9654
# Epoch 38/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2974 - acc: 0.9107 - val_loss: 0.1737 - val_acc: 0.9615
# Epoch 39/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.2397 - acc: 0.9271 - val_loss: 0.1750 - val_acc: 0.9615
# Epoch 40/50
# 17/17 [==============================] - 68s 4s/step - loss: 0.2491 - acc: 0.9280 - val_loss: 0.1760 - val_acc: 0.9615
# Epoch 41/50
# 17/17 [==============================] - 77s 5s/step - loss: 0.2775 - acc: 0.9261 - val_loss: 0.1733 - val_acc: 0.9615
# Epoch 42/50
# 17/17 [==============================] - 78s 5s/step - loss: 0.2150 - acc: 0.9405 - val_loss: 0.1747 - val_acc: 0.9615
# Epoch 43/50
# 17/17 [==============================] - 83s 5s/step - loss: 0.2151 - acc: 0.9357 - val_loss: 0.1754 - val_acc: 0.9577
# Epoch 44/50
# 17/17 [==============================] - 78s 5s/step - loss: 0.2740 - acc: 0.9299 - val_loss: 0.1726 - val_acc: 0.9577
# Epoch 45/50
# 17/17 [==============================] - 89s 5s/step - loss: 0.2406 - acc: 0.9415 - val_loss: 0.1728 - val_acc: 0.9577
# Epoch 46/50
# 17/17 [==============================] - 71s 4s/step - loss: 0.2226 - acc: 0.9386 - val_loss: 0.1754 - val_acc: 0.9615
# Epoch 47/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2358 - acc: 0.9453 - val_loss: 0.1741 - val_acc: 0.9577
# Epoch 48/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2167 - acc: 0.9424 - val_loss: 0.1750 - val_acc: 0.9577
# Epoch 49/50
# 17/17 [==============================] - 66s 4s/step - loss: 0.2224 - acc: 0.9319 - val_loss: 0.1756 - val_acc: 0.9615
# Epoch 50/50
# 17/17 [==============================] - 67s 4s/step - loss: 0.2219 - acc: 0.9415 - val_loss: 0.1749 - val_acc: 0.9577
# Avg Throughput: 20.161133137526804 imgs/sec

# %% [markdown]
# Now, let's compare the throughput achieved with and without auto-mixed precision enabled.

# %%
if arch == 'BDW|CORE|ATOM':
    import pandas as pd
    print(train_throughput_list)
    speedup = float(train_throughput_list[1])/float(train_throughput_list[0])
    print("Speedup : ", speedup)
    df = pd.DataFrame({'training_type':['orig', 'auto_mixed_precision'], 'Training Speedup':[1, speedup]})
    ax = df.plot.bar( x='training_type', y='Training Speedup', rot=0)
# Out:
# [21.73333016090273, 20.161133137526804]
# Speedup :  0.9276596356041082

# %% [markdown]
# ### Export the model in the SavedModel format
#
# Now that you've trained the model, export it as a SavedModel for reusing it later.

# %%
export_path = "models/resnet101_cropweed_model"
model.save(export_path)

export_path
# Out:
# 'models/resnet101_cropweed_model'

# %% [markdown]
# Let's measure the performance of the model we just saved using the `tf_benchmark.py` script that runs inference on dummy data.

# %%
# !python scripts/tf_benchmark.py --model_path models/resnet101_cropweed_model --num_warmup 5 --num_iter 50 --precision float32 --batch_size 32 --disable_optimize
# Out:
# 2023-03-27 22:34:37.712789: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 22:34:37.762528: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting:
# 2023-03-27 22:34:53.096524: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >=
# 2023-03-27 22:34:53.096930: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-03-27 22:34:56.608597: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >=
# 2023-03-27 22:34:56.608823: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# Find a possible input node: {'node_name': 'keras_layer_input', 'type': 'float32', 'shape': [224, 224, 3], 'is_one_dim': False}
# Find a possible output node: 'dense_6'
# 2023-03-27 22:35:00 [INFO] Final benchmark input nodes: name_list=['keras_layer_input'], shape_list=[(32, 224, 224, 3)], dtype_list=['float32']
# 2023-03-27 22:35:00 [INFO] Final benchmark output nodes: name_list=['dense_6']
# 2023-03-27 22:35:01.498125: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Iteration: 0, inference time: 2.4680492877960205 sec
# Iteration: 1, inference time: 1.241637945175171 sec
# Iteration: 2, inference time: 1.1756491661071777 sec
# Iteration: 3, inference time: 1.2876150608062744 sec
# Iteration: 4, inference time: 1.1836695671081543 sec
# Iteration: 5, inference time: 1.1599464416503906 sec
# Iteration: 6, inference time: 1.2696278095245361 sec
# Iteration: 7, inference time: 1.2252824306488037 sec
# Iteration: 8, inference time: 1.210197925567627 sec
# Iteration: 9, inference time: 1.5118904113769531 sec
# Iteration: 10, inference time: 1.3584856986999512 sec
# Iteration: 11, inference time: 1.1698906421661377 sec
# Iteration: 12, inference time: 1.1976642608642578 sec
# Iteration: 13, inference time: 1.196373462677002 sec
# Iteration: 14, inference time: 1.2094576358795166 sec
# Iteration: 15, inference time: 1.2439086437225342 sec
# Iteration: 16, inference time: 1.2189016342163086 sec
# Iteration: 17, inference time: 1.3829972743988037 sec
# Iteration: 18, inference time: 1.347719430923462 sec
# Iteration: 19, inference time: 1.296990156173706 sec
# Iteration: 20, inference time: 1.2805109024047852 sec
# Iteration: 21, inference time: 1.2839152812957764 sec
# Iteration: 22, inference time: 1.2658116817474365 sec
# Iteration: 23, inference time: 1.296544075012207 sec
# Iteration: 24, inference time: 1.288923978805542 sec
# Iteration: 25, inference time: 1.2787742614746094 sec
# Iteration: 26, inference time: 1.2521610260009766 sec
# Iteration: 27, inference time: 1.2552714347839355 sec
# Iteration: 28, inference time: 1.2660784721374512 sec
# Iteration: 29, inference time: 1.2504167556762695 sec
# Iteration: 30, inference time: 1.2505457401275635 sec
# Iteration: 31, inference time: 1.263568639755249 sec
# Iteration: 32, inference time: 1.304595947265625 sec
# Iteration: 33, inference time: 1.2746107578277588 sec
# Iteration: 34, inference time: 1.2580339908599854 sec
# Iteration: 35, inference time: 1.2635796070098877 sec
# Iteration: 36, inference time: 1.3819048404693604 sec
# Iteration: 37, inference time: 1.2672512531280518 sec
# Iteration: 38, inference time: 1.264176368713379 sec
# Iteration: 39, inference time: 1.2564644813537598 sec
# Iteration: 40, inference time: 1.3265612125396729 sec
# Iteration: 41, inference time: 1.2536587715148926 sec
# Iteration: 42, inference time: 1.4220890998840332 sec
# Iteration: 43, inference time: 1.3051908016204834 sec
# Iteration: 44, inference time: 1.2501258850097656 sec
# Iteration: 45, inference time: 1.2923030853271484 sec
# Iteration: 46, inference time: 1.2828748226165771 sec
# Iteration: 47, inference time: 1.2334446907043457 sec
# Iteration: 48, inference time: 1.3668644428253174 sec
# Iteration: 49, inference time: 1.2527785301208496 sec
# Batch size = 32
# Latency: 1276.502 ms
# Throughput: 25.07 fps

# %% [markdown]
# ### Optimize the SavedModel for faster inference
#
# To get a good performance on your (re)trained model for inference, some inference optimizations are required.
# In this section, we will guide you how to optimize a pre-trained model for better inference performance using the `freeze_optimize_v2.py` script that we put together using standard TensorFlow routines to optimize the model.
# Those optimizations includes:
#
# - Converting variables to constants
# - Removing training-only operations like checkpoint saving
# - Stripping out parts of the graph that are never reached
# - Removing debug operations like CheckNumerics
# - Folding batch normalization ops into the pre-calculated weights
# - Fusing common operations into unified versions
#
# The input to this script is the directory of original saved model, and output of this script is the directory of optimzed model. Users don't need to change below command in this tutorial, but need to put related directories after "--input_saved_model_dir" and "--output_saved_model_dir" for other pre-trained models.

# %%
# !python scripts/freeze_optimize_v2.py --input_saved_model_dir=models/resnet101_cropweed_model --output_saved_model_dir=models/resnet101_optimized_model
# Out:
# 2023-03-27 22:36:35.182994: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 22:36:35.185740: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting:
# 2023-03-27 22:36:38.989455: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >=
# 2023-03-27 22:36:38.989716: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# 2023-03-27 22:36:44.344824: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >=
# 2023-03-27 22:36:44.345039: I tensorflow/core/grappler/clusters/single_machine.cc:358] Starting new session
# WARNING:tensorflow:From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/strip_unused_lib.py:84: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# WARNING:tensorflow:From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:112: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.remove_training_nodes`
# 2023-03-27 22:38:16.430539: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting:
# WARNING:tensorflow:From /home/mnitin59/Downloads/Automated-Weed-Detection/scripts/freeze_optimize_v2.py:106: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# Optimized model is exported at: models/resnet101_optimized_model

# %% [markdown]
# Now that we have saved the optimized model, let's measure its performance using our benchmarking script.

# %%
# !python scripts/tf_benchmark.py --model_path models/resnet101_optimized_model --num_warmup 5 --num_iter 50 --precision float32 --batch_size 32
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2023-03-27 22:39:29 [WARNING] SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2023-03-27 22:39:29 [WARNING] SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2023-03-27 22:39:29.724844: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/neural_compressor/model/model.py:539: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# 2023-03-27 22:39:29 [WARNING] From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/neural_compressor/model/model.py:539: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# 2023-03-27 22:39:30 [INFO] Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:The specified SavedModel has no variables; no checkpoints were restored.
# 2023-03-27 22:39:30 [INFO] The specified SavedModel has no variables; no checkpoints were restored.
# Find a possible input node: {'node_name': 'keras_layer_input', 'type': 'float32', 'shape': [224, 224, 3], 'is_one_dim': False}
# Find a possible output node: 'Identity'
# 2023-03-27 22:39:31 [INFO] Final benchmark input nodes: name_list=['keras_layer_input'], shape_list=[(32, 224, 224, 3)], dtype_list=['float32']
# 2023-03-27 22:39:31 [INFO] Final benchmark output nodes: name_list=['Identity']
# WARNING:tensorflow:From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/strip_unused_lib.py:84: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2023-03-27 22:39:31 [WARNING] From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/strip_unused_lib.py:84: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# WARNING:tensorflow:From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:112: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.remove_training_nodes`
# 2023-03-27 22:39:31 [WARNING] From /home/mnitin59/anaconda3/envs/aikit-tf/lib/python3.9/site-packages/tensorflow/python/tools/optimize_for_inference_lib.py:112: remove_training_nodes (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.remove_training_nodes`
# ---- Optimize for inference!
# 2023-03-27 22:39:32.403981: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Iteration: 0, inference time: 2.064286231994629 sec
# Iteration: 1, inference time: 0.9375317096710205 sec
# Iteration: 2, inference time: 0.9835751056671143 sec
# Iteration: 3, inference time: 0.9390273094177246 sec
# Iteration: 4, inference time: 1.0472195148468018 sec
# Iteration: 5, inference time: 0.9628326892852783 sec
# Iteration: 6, inference time: 0.9525227546691895 sec
# Iteration: 7, inference time: 0.9368541240692139 sec
# Iteration: 8, inference time: 0.9531688690185547 sec
# Iteration: 9, inference time: 0.9170522689819336 sec
# Iteration: 10, inference time: 1.1362636089324951 sec
# Iteration: 11, inference time: 0.937077522277832 sec
# Iteration: 12, inference time: 0.94476318359375 sec
# Iteration: 13, inference time: 0.9456510543823242 sec
# Iteration: 14, inference time: 0.954359769821167 sec
# Iteration: 15, inference time: 1.4345450401306152 sec
# Iteration: 16, inference time: 1.4273567199707031 sec
# Iteration: 17, inference time: 1.2829439640045166 sec
# Iteration: 18, inference time: 0.9723865985870361 sec
# Iteration: 19, inference time: 0.9332008361816406 sec
# Iteration: 20, inference time: 0.9524857997894287 sec
# Iteration: 21, inference time: 1.072035312652588 sec
# Iteration: 22, inference time: 1.335312843322754 sec
# Iteration: 23, inference time: 1.380875825881958 sec
# Iteration: 24, inference time: 1.2097480297088623 sec
# Iteration: 25, inference time: 1.1232123374938965 sec
# Iteration: 26, inference time: 1.3970715999603271 sec
# Iteration: 27, inference time: 1.7499947547912598 sec
# Iteration: 28, inference time: 1.2432682514190674 sec
# Iteration: 29, inference time: 1.1254889965057373 sec
# Iteration: 30, inference time: 1.086761474609375 sec
# Iteration: 31, inference time: 1.0672471523284912 sec
# Iteration: 32, inference time: 1.0767745971679688 sec
# Iteration: 33, inference time: 1.0501058101654053 sec
# Iteration: 34, inference time: 1.0738499164581299 sec
# Iteration: 35, inference time: 1.065769910812378 sec
# Iteration: 36, inference time: 1.061065673828125 sec
# Iteration: 37, inference time: 1.0839011669158936 sec
# Iteration: 38, inference time: 1.3407385349273682 sec
# Iteration: 39, inference time: 1.5011405944824219 sec
# Iteration: 40, inference time: 1.070155143737793 sec
# Iteration: 41, inference time: 1.1376259326934814 sec
# Iteration: 42, inference time: 1.06965970993042 sec
# Iteration: 43, inference time: 1.131438970565796 sec
# Iteration: 44, inference time: 1.0711958408355713 sec
# Iteration: 45, inference time: 1.2845687866210938 sec
# Iteration: 46, inference time: 1.5641071796417236 sec
# Iteration: 47, inference time: 1.4080743789672852 sec
# Iteration: 48, inference time: 1.0555315017700195 sec
# Iteration: 49, inference time: 1.0038471221923828 sec
# Batch size = 32
# Latency: 1129.198 ms
# Throughput: 28.34 fps

# %% [markdown]
# **Let's compare the speedup obtained with the optimized model.**
#
# `plot.py` is a python script that creates a plot of the throughput values for inference with the original and the optimized model.

# %%
# !python scripts/plot.py
# Out:
# Throughput list:  [40.3336740958423, 51.99652304653568, 24.410872197613376, 25.068498141155832, 28.338707572065836]
# Speedup :  1.2891591012259311

# %% [markdown]
# ### TensorFlow Serving
#
# In this section, we will initialize and run TensorFlow Serving natively to serve our retrained model.

# %%
# !mkdir serving
# !cp -r models/resnet101_optimized_model serving/1
# Out:
# mkdir: cannot create directory ‘serving’: File exists

# %%
os.environ["MODEL_DIR"] = os.getcwd() + "/serving"

# %% [markdown]
# This is where we start running TensorFlow Serving and load our model. After it loads we can start making inference requests using REST. There are some important parameters:
# - **rest_api_port**: The port that you'll use for REST requests.
# - **model_name**: You'll use this in the URL of REST requests. It can be anything.
# - **model_base_path**: This is the path to the directory where you've saved your model.

# %%
# %%bash --bg
# nohup tensorflow_model_server --rest_api_port=8501 --model_name=rn50 --model_base_path=${MODEL_DIR} > server.log 2>&1

# %%
# !tail server.log

# %% [markdown]
# **Prepare the testing data for prediction**

# %%
for image_batch, labels_batch in val_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
test_data, test_labels = image_batch.numpy(), labels_batch.numpy()
# Out:
# (64, 224, 224, 3)
# (64,)

# %% [markdown]
# First, let's take a look at a random example from our test data.

# %%
import matplotlib.pyplot as plt

def show(idx, title):
    plt.figure()
    plt.imshow(test_data[idx])
    plt.axis('off')
    plt.title('\n\n{}'.format(title), fontdict={'size': 16})

import random
rando = random.randint(0,test_data.shape[0]-1)
show(rando, 'An Example Image:')

# %% [markdown]
# #### Make a request to your model in TensorFlow Serving
#
# Now let's create the JSON object for a batch of three inference requests, and see how well our model recognizes things:

# %%
import json
data = json.dumps({"signature_name": "serving_default", "instances": test_data[0:3].tolist()})
print('Data: {} ... {}'.format(data[:50], data[len(data)-52:]))
# Out:
# Data: {"signature_name": "serving_default", "instances": ... 9980164, 0.7038618326187134, 0.7038618326187134]]]]}

# %% [markdown]
# #### Make REST requests
#
# We'll send a predict request as a POST to our server's REST endpoint, and pass it three examples.

# %%
headers = {"content-type": "application/json"}
json_response = requests.post('http://localhost:8501/v1/models/rn50:predict', data=data, headers=headers)
predictions = json.loads(json_response.text)['predictions']

for i in range(0,3):
    show(i, 'The model thought this was a {} (class {}), and it was actually a {} (class {})'.format(
        class_names[np.argmax(predictions[i])], np.argmax(predictions[i]), class_names[test_labels[i]], test_labels[i]))

# %%
import time

start_time = time.time()
test_preds = model.predict(test_data)
end_time = time.time()

total_time = end_time - start_time
latency_speed = total_time / len(test_data)

print("Total time taken: {:.2f} seconds".format(total_time))
print("Latency speed: {:.2f} seconds per sample".format(latency_speed))
# Out:
# 2/2 [==============================] - 3s 2s/step
# Total time taken: 3.32 seconds
# Latency speed: 0.05 seconds per sample

# %%
# Convert the predictions from probabilities to class labels
test_preds_classes = np.argmax(test_preds, axis=-1)

# Print evaluation metrics
print("Classification Report:\n", classification_report(test_labels, test_preds_classes))
print("Cohen's Kappa:", cohen_kappa_score(test_labels, test_preds_classes))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00        31
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64
#
# Cohen's Kappa: 1.0

# %%
# Plot the confusion matrix
cm = confusion_matrix(test_labels, test_preds_classes)
classes = ['crop', 'weed']
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)

thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
# Compute fpr, tpr, and auc
fpr, tpr, _ = roc_curve(test_labels, test_preds[:, 1])
roc_auc = auc(fpr, tpr)

# Plot the AUC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
